# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
product_attribute = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Cleaned Data/Product Attributes.xlsx')
fz_meat = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Fz_Rfg Substitute Meat_POS_2020.xlsx')
fz_meat2 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Fz_Rfg Substitute Meat_POS_2021.xlsx')
fz_meat3 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Fz_Rfg Substitute Meat_POS_2022.xlsx')
fz_meat4 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Fz_Rfg Substitute Meat_POS_2023.xlsx')
fz_meat5 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Fz_Rfg Substitute Meat_POS_2024.xlsx')

# %%
product_attribute.head()
# Out:
#                                              Product  UPC 13 digit  \
# 0  AL SAFA HALAL FROZEN BEEF HOTDOG 12.6 OZ - 062...  624967436101
# 1  AL SAFA HALAL FROZEN CHICKEN FRANKFURTER 12 OZ...  624967508101
# 2  CLOVERDALE MEATS FROZEN BEEF AND PORK FRANKFUR...   76829017602
# 3  COUNTRY FRESH MEATS FROZEN PORK AND BEEF HOTDO...  829905000521
# 4   NOBRAND FROZEN BEEF HOTDOG 80 OZ - 0694022680771  694022680771
#
#                           Aisle Name Category Name Sub-Category Name  \
# 0  AISLE-FROZEN MEAT/POULTRY/SEAFOOD     MEAT - FZ   FZ FRANKFURTERS
# 1  AISLE-FROZEN MEAT/POULTRY/SEAFOOD     MEAT - FZ   FZ FRANKFURTERS
# 2  AISLE-FROZEN MEAT/POULTRY/SEAFOOD     MEAT - FZ   FZ FRANKFURTERS
# 3  AISLE-FROZEN MEAT/POULTRY/SEAFOOD     MEAT - FZ   FZ FRANKFURTERS
# 4  AISLE-FROZEN MEAT/POULTRY/SEAFOOD     MEAT - FZ   FZ FRANKFURTERS
#
#          Manufacturer Name Brand Franchise Name           Brand Name  \
# 0            AL SAFA HALAL        AL SAFA HALAL        AL SAFA HALAL
# 1            AL SAFA HALAL        AL SAFA HALAL        AL SAFA HALAL
# 2      CLOVERDALE FOODS CO           CLOVERDALE     CLOVERDALE MEATS
# 3  COUNTRY FRESH MEATS INC  COUNTRY FRESH MEATS  COUNTRY FRESH MEATS
# 4          FAIR MARKET INC              NOBRAND              NOBRAND
#
#          Package  Total Count  Total Ounces Form    Flavor / Scent  \
# 0  VACUUM PACKED          8.0          12.6  NaN           REGULAR
# 1  VACUUM PACKED          6.0          12.0  NaN           REGULAR
# 2            BOX         40.0         160.0  NaN           REGULAR
# 3  VACUUM PACKED          8.0          16.0  NaN      COLBY CHEESE
# 4            BOX         20.0          80.0  NaN  CHEDDAR JALAPENO
#
#      Meat Source Product Type Type Of Meat Substituted Type Of Substitute  \
# 0           BEEF      HOT DOG                      NaN                NaN
# 1        CHICKEN  FRANKFURTER                      NaN                NaN
# 2  BEEF AND PORK  FRANKFURTER                      NaN                NaN
# 3  PORK AND BEEF      HOT DOG                      NaN                NaN
# 4           BEEF      HOT DOG                      NaN                NaN
#
#   Cooked Info
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
fz_meat.count()
# Out:
# Geography                                          221397
# Time                                               221397
# Product                                            221397
# UPC 13 digit                                       221397
# Unit Sales                                         221397
# Unit Sales No Merch                                217766
# Unit Sales Any Merch                               143217
# Unit Sales Price Reductions Only                   137308
# Unit Sales Feature Only                             25455
# Unit Sales Display Only                             38319
# Unit Sales Special Pack Only                            0
# Unit Sales Feature and Display                       4936
# Volume Sales                                       221397
# Volume Sales No Merch                              217766
# Volume Sales Any Merch                             143217
# Volume Sales Price Reductions Only                 137308
# Volume Sales Feature Only                           25455
# Volume Sales Display Only                           38319
# Volume Sales Special Pack Only                          0
# Volume Sales Feature and Display                     4936
# Dollar Sales                                       221397
# Dollar Sales No Merch                              217766
# Dollar Sales Any Merch                             143217
# Dollar Sales Price Reductions Only                 137308
# Dollar Sales Feature Only                           25455
# Dollar Sales Display Only                           38319
# Dollar Sales Special Pack Only                          0
# Dollar Sales Feature and Display                     4936
# Price per Unit                                     221397
# Price per Unit No Merch                            217766
# Price per Unit Any Merch                           143217
# Price per Unit Price Reductions Only               137308
# Price per Unit Feature Only                         25455
# Price per Unit Display Only                         38319
# Price per Unit Special Pack Only                        0
# Price per Unit Feature and Display                   4936
# Price per Volume                                   221397
# Price per Volume No Merch                          217766
# Price per Volume Any Merch                         143217
# Price per Volume Price Reductions Only             137308
# Price per Volume Feature Only                       25455
# Price per Volume Display Only                       38319
# Price per Volume Special Pack Only                      0
# Price per Volume Feature and Display                 4936
# Base Unit Sales                                    221397
# Base Volume Sales                                  221397
# Base Dollar Sales                                  221397
# Incremental Units                                  143217
# Incremental Volume                                 143217
# Incremental Dollars                                143217
# ACV Weighted Distribution                          221397
# ACV Weighted Distribution No Merch                 217766
# ACV Weighted Distribution Any Merch                143217
# ACV Weighted Distribution Price Reductions Only    137308
# ACV Weighted Distribution Feature Only              25455
# ACV Weighted Distribution Display Only              38319
# ACV Weighted Distribution Special Pack Only             0
# ACV Weighted Distribution Feature and Display        4936
# dtype: int64

# %%
# Imputation
def imputation_process(row):
    row['Incremental Units'] = row['Unit Sales'] - row['Base Unit Sales']
    row['Incremental Volume'] = row['Volume Sales'] - row['Base Volume Sales']
    row['Incremental Dollars'] = row['Dollar Sales'] - row['Base Dollar Sales']
    return row

# Split Geography column and only save its location
def extract_location(col):
    return col.split(' - ')[0]

# convert time into year month and day
def parse_time(col):
    # Year, month, day
    sep_data = col.split('-')
    year = int('20' + sep_data[2])
    month = int(sep_data[0][-2:])
    day = int(sep_data[1])
    # Quarter of given date
    quarter = (month - 1) // 3 + 1
    return pd.Series([year, quarter, month], index = ['Year', 'Quarter', 'Month'])

# Split product column and only save company name and product name
def parse_product(col):  
    return col.split(' - ')[0]


# Based on length of company name, select product name
def extract_product_name(full_string, brand_name):
    brand_name_length = len(brand_name)
    words = full_string[brand_name_length:].strip()
    return words

# # Arrange columns order
def change_column_order(df):
    final_order = [
        'Geography', 'Year', 'Quarter', 'Month', 'Season', 'Form', 'Manufacturer Name',
        'Brand Name', 'Product Name', 'Flavor / Scent', 'Meat Source',
        'Unit Sales', 'Volume Sales', 'Dollar Sales', 'Price per Unit', 
        'Price per Volume', 'Base Unit Sales', 'Base Volume Sales', 'Base Dollar Sales',
        'Incremental Units', 'Incremental Volume', 'Incremental Dollars', 
        'ACV Weighted Distribution'
    ]
    return df[final_order]

def merge_content(df1, df2):
    combined = df1.merge(df2, how = 'left', on = 'Product')
    return combined

def map_season(month):
    # Northern Hemisphere standard mapping
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Fall'


# Full tranform process
def transform_data(df, df2):
    table1 = merge_content(df, df2)
    # Used customized function
    table1['Geography'] = table1['Geography'].map(extract_location)
    table1[['Year', 'Quarter', 'Month']] = table1['Time'].apply(parse_time)
    table1['Product'] = table1['Product'].map(parse_product)
    table1['Product Name'] = table1.apply(lambda row: extract_product_name(row['Product'], row['Brand Name']), axis=1)
    #df['Product Name'] = df.apply(extract_product_name(df['Product'], df['Brand']), axis = 1)
    
    # Mapping quarter to seasonality
    table1['Season'] = table1['Month'].apply(map_season)
    # Change column order
    transformed = change_column_order(table1).apply(imputation_process, axis = 1)
    return transformed

# %%
combined = transform_data(fz_meat, product_attribute)
combined2 = transform_data(fz_meat2, product_attribute)
combined3 = transform_data(fz_meat3, product_attribute)
combined4 = transform_data(fz_meat4, product_attribute)
combined5 = transform_data(fz_meat5, product_attribute)

# %%
full_fz_rfg_sub = pd.concat([combined, combined2, combined3, combined4, combined5])

# %%
full_fz_rfg_sub.head()
# Out:
#   Geography  Year  Quarter  Month  Season          Form Manufacturer Name  \
# 0  Total US  2020        1      1  Winter        GROUND      AB FOODS LLC
# 1  Total US  2020        1      1  Winter          BALL      AB FOODS LLC
# 2  Total US  2020        1      1  Winter  BURGER PATTY   ALPHA FOODS INC
# 3  Total US  2020        1      1  Winter       CRUMBLE   ALPHA FOODS INC
# 4  Total US  2020        1      1  Winter         PATTY   ALPHA FOODS INC
#
#   Brand Name                                       Product Name  \
# 0      MATCH    FROZEN GROUND BEEF MEAT SUBSTITUTE GROUND 16 OZ
# 1      MATCH  FROZEN ITALIAN SAUSAGE MEAT SUBSTITUTE BALL 16 OZ
# 2      ALPHA  FROZEN ORIGINAL BEEFY MEAT SUBSTITUTE BURGER P...
# 3      ALPHA  FROZEN ORIGINAL BEEFY MEAT SUBSTITUTE CRUMBLE ...
# 4      ALPHA          FROZEN REGULAR MEAT SUBSTITUTE PATTY 8 OZ
#
#     Flavor / Scent  ...  Dollar Sales  Price per Unit  Price per Volume  \
# 0      GROUND BEEF  ...    419.220014        8.490000          8.490000
# 1  ITALIAN SAUSAGE  ...    326.519271        8.490000          8.490000
# 2   ORIGINAL BEEFY  ...    620.552626        5.990000         11.980000
# 3   ORIGINAL BEEFY  ...     54.802908        5.801781         11.603562
# 4          REGULAR  ...     37.281130        6.329463         12.658927
#
#    Base Unit Sales  Base Volume Sales  Base Dollar Sales  Incremental Units  \
# 0        49.378093          49.378093         419.220014                0.0
# 1        38.459278          38.459278         326.519271                0.0
# 2       103.598101          51.799051         620.552626                0.0
# 3         9.445876           4.722938          54.802908                0.0
# 4         5.890093           2.945047          37.281130                0.0
#
#    Incremental Volume  Incremental Dollars  ACV Weighted Distribution
# 0                 0.0                  0.0                   0.066628
# 1                 0.0                  0.0                   0.058680
# 2                 0.0                  0.0                   0.193509
# 3                 0.0                  0.0                   0.005675
# 4                 0.0                  0.0                   0.003585
#
# [5 rows x 23 columns]

# %%
#test = fz_meat.merge(product_attribute, how = 'left', on = 'Product')
full_fz_rfg_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 991780 entries, 0 to 12727
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Geography                  991780 non-null  object
#  1   Year                       991780 non-null  int64
#  2   Quarter                    991780 non-null  int64
#  3   Month                      991780 non-null  int64
#  4   Season                     991780 non-null  object
#  5   Form                       991780 non-null  object
#  6   Manufacturer Name          991780 non-null  object
#  7   Brand Name                 991780 non-null  object
#  8   Product Name               991780 non-null  object
#  9   Flavor / Scent             991780 non-null  object
#  10  Meat Source                0 non-null       float64
#  11  Unit Sales                 991780 non-null  float64
#  12  Volume Sales               991780 non-null  float64
#  13  Dollar Sales               991780 non-null  float64
#  14  Price per Unit             991780 non-null  float64
#  15  Price per Volume           991780 non-null  float64
#  16  Base Unit Sales            991780 non-null  float64
#  17  Base Volume Sales          991780 non-null  float64
#  18  Base Dollar Sales          991780 non-null  float64
#  19  Incremental Units          991780 non-null  float64
#  20  Incremental Volume         991780 non-null  float64
#  21  Incremental Dollars        991780 non-null  float64
#  22  ACV Weighted Distribution  991780 non-null  float64
# dtypes: float64(13), int64(3), object(7)
# memory usage: 181.6+ MB

# %%
full_fz_rfg_sub['Form'].unique()
# Out:
# array(['GROUND', 'BALL', 'BURGER PATTY', 'CRUMBLE', 'PATTY', 'BURGER',
#        'LINK', 'MEATBALL', 'PIECE', 'SLICED', 'STEAK', 'SPARE RIBS',
#        'CHUNK', 'TIP', 'SLICE', 'BREAKFAST PATTY', 'FILET', 'SLIDER',
#        'CAKE', 'STRIP', 'BITE', 'POPPER', 'BREAKFAST SAUSAGE PATTY',
#        'HOT DOG', 'PULLED', 'BREAKFAST LINK', 'FRANK', 'ROAST', 'WHOLE',
#        'STICK', 'NOT STATED ON PACKAGE', 'BLOCK', 'ROLL', 'NUGGET',
#        'BREAST', 'FINGER', 'TENDER', 'WING', 'CUTLET', 'DICED', 'POPCORN',
#        'DIPPER', 'BREAKFAST BITES', 'CHUB', 'DINNER SAUSAGE LINK', 'CUBE',
#        'BAR', 'LOAF', 'MEAT LOAF', 'BRATWURST', 'BREAKFAST SAUSAGE ROLL',
#        'SPLIT ROPE', 'ROPE', 'ULTRA THIN SLICE', 'DELI SLICED', 'CUT',
#        'BREAKFAST SAUSAGE LINK', 'GIZZARD', 'RIBLET', 'SAUSAGE',
#        'DINNER LINK', 'DRUMSTICK', 'FUN NUGGETS', 'SHREDS', 'SHREDDED',
#        'FRIES', 'TENDERS', 'BINGS', 'SAUSAGE PATTY', 'BAO BUN'],
#       dtype=object)

# %%
# Wrapping up
# Morningstars marketshare
# Impossible marketsharex
# Combine Gardein & Gardein ultimate plant-based dollar sales
# Percentage Sales in Tender & Nug from MORNINGSTAR FARMS INCOGMEATO & GARDEIN ULTIMATE PLANT BASED & IMPOSSIBLE (or maybe top 3 sales company)
# Combine geography vizs with top 3 company

# %%
# NUMERIC CORRELATION IS USELESS
# corrmat = combined[numeric_col].corr().round(2)
# top_corr_features = corrmat.index
# plt.figure(figsize=(7, 7))
# sns.heatmap(combined[top_corr_features].corr(),annot=True, square=True, fmt='.2f',
#             cbar_kws={"shrink": .80}, linewidths=.5, cmap='RdYlGn');

# %%
# output_file = '/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/test_merge.csv'
# combined.to_csv(output_file, index=False)

# %% [markdown]
# ## Analysis on TOP 10 Manufacture & Sales

# %%
brand_sales = full_fz_rfg_sub.groupby('Brand Name')['Dollar Sales'].sum().reset_index()
total_market_sales = brand_sales['Dollar Sales'].sum()
brand_sales['Market Share (%)'] = (brand_sales['Dollar Sales'] / total_market_sales) * 100
new_brand_sales = brand_sales.sort_values('Market Share (%)', ascending = False).head(10)

# Set up the matplotlib figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))  # 20 width, 8 height for the whole figure

# Pie chart on the first subplot
ax1.pie(new_brand_sales['Market Share (%)'], labels=new_brand_sales['Brand Name'], autopct='%1.1f%%', startangle=140)
ax1.set_title('Market Share by Brand (Dollar Sales)')

# Bar chart on the second subplot
sns.barplot(x='Market Share (%)', y='Brand Name', data=new_brand_sales, palette='viridis', ax=ax2)
ax2.set_title('Market Share by Brand (Dollar Sales)')
ax2.set_xlabel('Market Share (%)')
ax2.set_ylabel('Brand Name')

# Adjust the layout so the plots are not overlapping
plt.tight_layout()
plt.subplots_adjust(wspace=0.65) 
# Show the combined figure with both plots
plt.show()

# %%
# Sales that products are in the form (type of product) of 'Nugget'
nug_df = full_fz_rfg_sub[full_fz_rfg_sub['Form'] == 'NUGGET']
nug_df_sales = nug_df.groupby(['Brand Name']).agg({'Dollar Sales':'sum'}).sort_values('Dollar Sales', ascending = False).reset_index()
nug_df_sales.head()
# Out:
#                      Brand Name  Dollar Sales
# 0             MORNINGSTAR FARMS  2.521267e+08
# 1                    IMPOSSIBLE  9.746890e+07
# 2                         QUORN  7.791269e+07
# 3  GARDEIN ULTIMATE PLANT BASED  4.910115e+07
# 4                SIMULATE NUGGS  3.717600e+07

# %%
# Sales that products are in the form (type of product) of 'Tender'
tender_df = full_fz_rfg_sub[full_fz_rfg_sub['Form'] == 'TENDER']
tender_df_sales = tender_df.groupby(['Brand Name']).agg({'Dollar Sales':'sum'}).sort_values('Dollar Sales', ascending = False).reset_index()
tender_df_sales.head()
# Out:
#                      Brand Name  Dollar Sales
# 0                       GARDEIN  1.497733e+08
# 1  GARDEIN ULTIMATE PLANT BASED  7.054408e+07
# 2                 PRIVATE LABEL  3.682886e+07
# 3                   BEYOND MEAT  2.221151e+07
# 4  MORNINGSTAR FARMS INCOGMEATO  2.046105e+07

# %%
# Total Sales of each Company regardless any attributes
total_sales = full_fz_rfg_sub.groupby(['Brand Name']).agg({'Dollar Sales':'sum'}).sort_values('Dollar Sales', ascending = False).reset_index()
total_sales.head()
# Out:
#                   Brand Name  Dollar Sales
# 0          MORNINGSTAR FARMS  2.059644e+09
# 1                 IMPOSSIBLE  1.015503e+09
# 2                    GARDEIN  9.404258e+08
# 3  BEYOND MEAT BEYOND BURGER  4.844174e+08
# 4                BEYOND MEAT  4.811132e+08

# %%
# Emerge total sales & nugget
merge_sales_nug = total_sales.merge(nug_df_sales, how = 'left', on = 'Brand Name')
merge_sales_nug['Percentage'] = (merge_sales_nug['Dollar Sales_y'] / merge_sales_nug['Dollar Sales_x'] * 100).round(4)
merge_sales_nug = merge_sales_nug.dropna().sort_values('Percentage', ascending = False)

# %%
# Emerge total sales & tender
merge_sales_tender = total_sales.merge(tender_df_sales, how = 'left', on = 'Brand Name')
merge_sales_tender['Percentage'] = (merge_sales_tender['Dollar Sales_y'] / merge_sales_tender['Dollar Sales_x'] * 100).round(4)
merge_sales_tender = merge_sales_tender.dropna().sort_values('Percentage', ascending = False)

# %%
# Filtered data that only includes top 3 sales company
filtered_nug_df = merge_sales_nug[merge_sales_nug['Brand Name'].str.contains('Impossible|Gardein|Morningstars', case=False, na=False)]
filtered_tender_df = merge_sales_tender[merge_sales_tender['Brand Name'].str.contains('Impossible|Gardein|Morningstar', case=False, na=False)]

# %%
filtered_nug_df
# Out:
#                       Brand Name  Dollar Sales_x  Dollar Sales_y  Percentage
# 38       IMPOSSIBLE WILD NUGGIES    2.150508e+07    2.150508e+07    100.0000
# 11  GARDEIN ULTIMATE PLANT BASED    2.455504e+08    4.910115e+07     19.9964
# 1                     IMPOSSIBLE    1.015503e+09    9.746890e+07      9.5981
# 2                        GARDEIN    9.404258e+08    5.843099e+06      0.6213

# %%
filtered_tender_df
# Out:
#                       Brand Name  Dollar Sales_x  Dollar Sales_y  Percentage
# 11  GARDEIN ULTIMATE PLANT BASED    2.455504e+08    7.054408e+07     28.7290
# 21  MORNINGSTAR FARMS INCOGMEATO    7.257893e+07    2.046105e+07     28.1914
# 2                        GARDEIN    9.404258e+08    1.497733e+08     15.9261
# 1                     IMPOSSIBLE    1.015503e+09    2.289344e+06      0.2254

# %% [markdown]
# # GARDEIN
# There are two brands under gardein Inc. One named Gardein Ultimate Plant Based, One named Gardein. The previous one only sell plant-based products, the second one sell both plant-based or non plant-based products. But in this case, it indicates they both sell plant-based products.
# Whether it's regarding tender or nuggets, it take majority of marketshares
# # IMPOSSIBLE
# Impossible Wild Nuggies is a certain brand that is designed to only produce and sell plant-based nuggets, thus its nuggets product take 100% marketshares. However, tender from Impossible is only a small portion of its product series.
# # Morningstar
# Whether it's nugget or tender, morningstar has a good performance on selling both. And take company's profit by approximately above 20%

# %% [markdown]
# # Analysis on Sales Distribution, Focusing on Sales Per Unit

# %%
selected_brands = ["Impossible", "Gardein", "Morningstar"]
no_outliers_price_descriptive_stats = full_fz_rfg_sub[full_fz_rfg_sub['Price per Unit'] < 10]
no_outliers_price_descriptive_stats = no_outliers_price_descriptive_stats[no_outliers_price_descriptive_stats['Brand Name'].str.contains('Impossible|Gardein|Morningstar', case=False, na=False)]

# %%
# Price Analysis: Study the price per unit to understand pricing strategies or to identify if there's a correlation between price and sales volume.
#price_descriptive_stats = full_fz_rfg_sub['Price per Unit'].describe()
price_descriptive_stats = no_outliers_price_descriptive_stats['Price per Unit'].describe()
print(price_descriptive_stats)

# Distribution of 'Price per Unit'
plt.figure(figsize=(10, 6))
sns.histplot(no_outliers_price_descriptive_stats['Price per Unit'], kde=True)
plt.title('Distribution of Price per Unit')
plt.xlabel('Price per Unit')
plt.ylabel('Frequency')
plt.show()

# Boxplot for 'Price per Unit'
plt.figure(figsize=(10, 6))
sns.boxplot(x=no_outliers_price_descriptive_stats['Price per Unit'])
plt.title('Boxplot of Price per Unit')
plt.xlabel('Price per Unit')
plt.show()

# Correlation analysis
correlation_matrix = no_outliers_price_descriptive_stats[['Price per Unit', 'Dollar Sales']].corr()
print(correlation_matrix)

# Scatter plot of 'Price per Unit' vs 'Dollar Sales'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=no_outliers_price_descriptive_stats, x='Price per Unit', y='Dollar Sales')
plt.title('Price per Unit vs Dollar Sales')
plt.xlabel('Price per Unit')
plt.ylabel('Dollar Sales')
plt.show()
# Out:
# count    180861.000000
# mean          5.438889
# std           1.587389
# min           0.370000
# 25%           4.264800
# 50%           4.964491
# 75%           6.470000
# max           9.999656
# Name: Price per Unit, dtype: float64
#                 Price per Unit  Dollar Sales
# Price per Unit        1.000000      0.014413
# Dollar Sales          0.014413      1.000000

# %% [markdown]
# It's clearly that when price of a product is between (0, 10), the sales reach high point. However, there are several product that has sales above 20, but none of their sales reach to even 1.0*1e6 unit of sales, and there are considered as outliers.
# <strong>We can remove them since the amount of outliers, compared to majority of data, is less.<Strong>

# %%
seasonal_sales = full_fz_rfg_sub.groupby(['Season', 'Brand Name'])['Dollar Sales'].sum().reset_index()
seasonal_sales = seasonal_sales[seasonal_sales['Brand Name'].str.contains('Impossible|Gardein|Morningstar', case=False, na=False)]
seasonal_sales['Season'] = pd.Categorical(seasonal_sales['Season'], categories=['Spring', 'Summer', 'Fall', 'Winter'], ordered=True)

# Plot the bar chart using seaborn
plt.figure(figsize=(15, 6))
sns.barplot(x='Season', y='Dollar Sales', hue='Brand Name', data=seasonal_sales)

plt.title('Company Performance by Season')
plt.xlabel('Season')
plt.ylabel('Dollar Sales')
plt.legend(title='Brand Name', loc='upper left', bbox_to_anchor=(1, 1), frameon=False)
plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust the right parameter as needed
plt.show()

# %%
# Seasonality: Since the data includes a 'Season' column, you can examine seasonal trends in sales to determine if certain products sell better in certain seasons.
# Step 1: Aggregate Sales by Season
# # Step 2: Visualize Sales Trends by Season
# plt.figure(figsize=(10, 6))
# sns.barplot(data=seasonal_sales, x='Season', y='Dollar Sales')
# plt.title('Total Dollar Sales by Season')
# plt.xlabel('Season')
# plt.ylabel('Total Dollar Sales')
# plt.show()

# %% [markdown]
# For all meat alternative products, sales difference in seasonality is not big, however, sales in Spring still higher than the rest season

# %% [markdown]
# # Analysis: Sales by Location

# %%
# Geographical Analysis: The 'Geography' column can be used to determine regional preferences or sales performance.
geo_sales_summary = full_fz_rfg_sub.groupby(['Geography','Brand Name'])['Dollar Sales'].agg(['sum', 'mean', 'count']).reset_index()
geo_sales_summary = geo_sales_summary[geo_sales_summary['Brand Name'].str.contains('Impossible|Gardein|Morningstar', case=False, na=False)]
geo_sales_summary = geo_sales_summary[geo_sales_summary['Geography'] != 'Total US']

# Pivot table
pivot_df = geo_sales_summary.pivot(index='Geography', columns='Brand Name', values='sum')

# Now create a stacked bar plot.
pivot_df.plot(kind='bar', stacked=True, figsize=(12, 8))

plt.title('Dollar Sales by Location and Company')
plt.xlabel('Geography')
plt.ylabel('Dollar Sales')

# Rotate the x-axis labels if there are many categories or if they are long
plt.xticks(rotation=45)

plt.legend(title='Brand Name', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout(rect=[0,0,0.9,1])  # Adjust this if your legend still overlaps

plt.show()

# %% [markdown]
# Pattern:
# 1. Except mid region of U.S. such as Plains and South Central, all other regions have higher sales of meat alternative, especially in Northeast and Southeast.
# 2. This Probably because in mid region, people prefer to eat meat
# 3. It might be associated with slaughter industry

# %% [markdown]
# ## Analysis: Seasonality

# %%
# Time Series Analysis: Use the 'Year', 'Quarter', and 'Month' columns to perform a time series analysis to see sales trends over time.

from statsmodels.tsa.seasonal import seasonal_decompose
seasonality_df = full_fz_rfg_sub[full_fz_rfg_sub['Brand Name'].str.contains('Impossible|Gardein|Morningstar', case=False, na=False)].sort_index()
seasonality_df = seasonality_df[seasonality_df['Geography'] != 'Total US']
# Time Series Analysis: Use the 'Year', 'Quarter', and 'Month' columns to perform a time series analysis to see sales trends over time.
seasonality_df['Date'] = pd.to_datetime(seasonality_df['Year'].astype(str) + '-' + (seasonality_df['Month']).astype(str))

# Step 2: Aggregate Sales Over Time
# Set the date as the index and sort it
seasonality_df.set_index('Date', inplace=True)
seasonality_df.sort_index(inplace=True)

# Resample the data monthly and sum up the sales
monthly_sales = seasonality_df['Dollar Sales'].resample('M').sum()

# Step 3: Visualize Sales Trends
plt.figure(figsize=(12, 6))
monthly_sales.plot(title='Monthly Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Dollar Sales')
plt.show()

# Step 4: Decompose the Time Series
result = seasonal_decompose(monthly_sales, model='additive')
result.plot()
plt.show()

# %% [markdown]
# Pattern
# 1. Data in 2024 is not sufficient
# 2. In each year, sales reach to high point and gradually decrease by the time until the end of the year
# 3. It might because
#     1. Spring produce more vegetables
#     2. Hot weather in Summer make people have less appetize
#     3. People tend to eat foods with high-energy, high-calories
# 4. The overall trend of meat alternative sales is in decrease

# %%
# Filter data
filtered_df = full_fz_rfg_sub[full_fz_rfg_sub['Geography'] != 'Total US']
filtered_df = filtered_df[filtered_df['Brand Name'].str.contains('Impossible|Gardein|Morningstar', case=False, na=False)].sort_index()
# Step 1: Create a Pivot Table
pivot_table = filtered_df.pivot_table(
    values='Dollar Sales', 
    index=['Geography', 'Season'], 
    aggfunc='sum'
).sort_index()

# Step 2: Visualize Data
# For a simple heatmap:
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table.unstack(level='Season'), cmap='coolwarm', annot=True, fmt=".1f")
plt.title('Seasonal Sales by Geography')
plt.xlabel('Season')
plt.ylabel('Geography')
plt.show()

# For bar charts, if you want to compare seasons across geographies:
pivot_table.unstack().plot(kind='bar', subplots=True, layout=(2,2), figsize=(15, 10), sharey=True)
plt.suptitle('Seasonal Sales by Geography')
plt.show()

# Step 3: Statistical Analysis
# Depending on your requirements, you might perform an ANOVA test, time series decomposition, etc.
