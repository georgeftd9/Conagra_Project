# %%
import pandas as pd

# %%
rfg_frankfurters = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Frankfurters_POS_2020.xlsx')
rfg_frankfurters2 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Frankfurters_POS_2021.xlsx')
rfg_frankfurters3 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Frankfurters_POS_2022.xlsx')
rfg_frankfurters4 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Frankfurters_POS_2023.xlsx')
rfg_frankfurters5 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Frankfurters_POS_2024.xlsx')
product_attribute = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Cleaned Data/Product Attributes.xlsx')

# %%
rfg_frankfurters.head()
# Out:
#                         Geography                  Time  \
# 0  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 1  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 2  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 3  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 4  Total US - Multi Outlet + Conv  Week Ending 01-12-20
#
#                                              Product  UPC 13 digit  \
# 0  3 SISTERS REFRIGERATED BEEF FRANKFURTER 4 CT 1...  858121002001
# 1  SAUGY REFRIGERATED BEEF AND PORK FRANKFURTER 2...  609683012121
# 2  ABELES & HEYMANN REFRIGERATED BEEF FRANKFURTER...  653694613051
# 3  ABELES & HEYMANN REFRIGERATED BEEF FRANKFURTER...  653694100201
# 4  ABELES & HEYMANN REFRIGERATED BEEF FRANKFURTER...  653694100101
#
#    Unit Sales  Volume Sales  Dollar Sales  Price per Unit  Price per Volume  \
# 0    4.215772      4.215772     33.684019        7.990000          7.990000
# 1  142.476028    356.190071   2278.191693       15.990000          6.396000
# 2   50.474860     37.856145    428.420430        8.487798         11.317064
# 3   10.270150      7.702612     85.735715        8.348049         11.130732
# 4  106.943064     80.207298    967.924723        9.050841         12.067789
#
#    Base Unit Sales  Base Volume Sales  Base Dollar Sales  Incremental Units  \
# 0         4.215772           4.215772          33.684019                NaN
# 1       142.476028         356.190071        2278.191693                NaN
# 2        48.035803          36.026852         428.257783           2.439057
# 3        10.270150           7.702612          85.735715                NaN
# 4       106.943064          80.207298         967.924723                NaN
#
#    Incremental Volume  Incremental Dollars  ACV Weighted Distribution
# 0                 NaN                  NaN                   0.002049
# 1                 NaN                  NaN                   0.137421
# 2            1.829293             0.162647                   0.094506
# 3                 NaN                  NaN                   0.019876
# 4                 NaN                  NaN                   0.173619

# %%
# Imputation
def imputation_process(row):
    row['Incremental Units'] = row['Unit Sales'] - row['Base Unit Sales']
    row['Incremental Volume'] = row['Volume Sales'] - row['Base Volume Sales']
    row['Incremental Dollars'] = row['Dollar Sales'] - row['Base Dollar Sales']
    return row

# Split Geography column and only save its location
def extract_location(col):
    return col.split(' - ')[0]

# convert time into year month and day
def parse_time(col):
    # Year, month, day
    sep_data = col.split('-')
    year = int('20' + sep_data[2])
    month = int(sep_data[0][-2:])
    day = int(sep_data[1])
    # Quarter of given date
    quarter = (month - 1) // 3 + 1
    return pd.Series([year, quarter, month], index = ['Year', 'Quarter', 'Month'])

# Split product column and only save company name and product name
def parse_product(col):  
    return col.split(' - ')[0]


# Based on length of company name, select product name
def extract_product_name(full_string, brand_name):
    brand_name_length = len(brand_name)
    words = full_string[brand_name_length:].strip()
    return words

# # Arrange columns order
def change_column_order(df):
    final_order = [
        'Geography', 'Year', 'Quarter', 'Manufacturer Name',
        'Brand Name', 'Product Name', 'Flavor / Scent', 'Meat Source',
        'Unit Sales', 'Volume Sales', 'Dollar Sales', 'Price per Unit', 
        'Price per Volume', 'Base Unit Sales', 'Base Volume Sales', 'Base Dollar Sales',
        'Incremental Units', 'Incremental Volume', 'Incremental Dollars', 
        'ACV Weighted Distribution'
    ]
    return df[final_order]

def merge_content(df1, df2):
    combined = df1.merge(df2, how = 'left', on = 'Product')
    return combined

def map_season(month):
    # Northern Hemisphere standard mapping
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Fall'


# Full tranform process
def transform_data(df, df2):
    table1 = merge_content(df, df2)
    # Used customized function
    table1['Geography'] = table1['Geography'].map(extract_location)
    table1[['Year', 'Quarter', 'Month']] = table1['Time'].apply(parse_time)
    table1['Product'] = table1['Product'].map(parse_product)
    table1['Product Name'] = table1.apply(lambda row: extract_product_name(row['Product'], row['Brand Name']), axis=1)
    #df['Product Name'] = df.apply(extract_product_name(df['Product'], df['Brand']), axis = 1)
    
    # Mapping quarter to seasonality
    table1['Season'] = table1['Month'].apply(map_season)
    # Change column order
    transformed = change_column_order(table1).apply(imputation_process, axis = 1)
    return transformed

# %%
rfg_frankfurters_2020 = transform_data(rfg_frankfurters, product_attribute)
rfg_frankfurters_2021 = transform_data(rfg_frankfurters2, product_attribute)
rfg_frankfurters_2022 = transform_data(rfg_frankfurters3, product_attribute)
rfg_frankfurters_2023 = transform_data(rfg_frankfurters4, product_attribute)
rfg_frankfurters_2024 = transform_data(rfg_frankfurters5, product_attribute)

# %%
# Combined & export
full_rfg_frankfurters = pd.concat([rfg_frankfurters_2020, rfg_frankfurters_2021, rfg_frankfurters_2022, rfg_frankfurters_2023, rfg_frankfurters_2024])
output_file = '/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/full_rfg_frankfurters.csv'
full_rfg_frankfurters.to_csv(output_file, index=False)
