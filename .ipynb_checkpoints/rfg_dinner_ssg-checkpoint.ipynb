# %%
import pandas as pd

# %%
rfg_dinner_ssg = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Dinner Ssg_POS_2020.xlsx')
rfg_dinner_ssg2 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Dinner Ssg_POS_2021.xlsx')
rfg_dinner_ssg3 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Dinner Ssg_POS_2022.xlsx')
rfg_dinner_ssg4 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Dinner Ssg_POS_2023.xlsx')
rfg_dinner_ssg5 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Dinner Ssg_POS_2024.xlsx')
product_attribute = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Cleaned Data/Product Attributes.xlsx')

# %%
rfg_dinner_ssg
# Out:
#                                     Geography                  Time  \
# 0              Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 1              Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 2              Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 3              Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 4              Total US - Multi Outlet + Conv  Week Ending 01-12-20
# ...                                       ...                   ...
# 704185  West - Standard - Multi Outlet + Conv  Week Ending 01-03-21
# 704186  West - Standard - Multi Outlet + Conv  Week Ending 01-03-21
# 704187  West - Standard - Multi Outlet + Conv  Week Ending 01-03-21
# 704188  West - Standard - Multi Outlet + Conv  Week Ending 01-03-21
# 704189  West - Standard - Multi Outlet + Conv  Week Ending 01-03-21
#
#                                                   Product  UPC 13 digit  \
# 0       SOUTHFORK SAUSAGE REFRIGERATED PORK AND BEEF S...  824766000351
# 1       SOUTHFORK SAUSAGE REFRIGERATED PORK ITALIAN SA...  824766000111
# 2       ABELES & HEYMANN REFRIGERATED BEEF FAT SAUSAGE...  653694935271
# 3       ABELES & HEYMANN REFRIGERATED BEEF ITALIAN SAU...  653694093471
# 4       ABELES & HEYMANN REFRIGERATED BEEF ITALIAN SAU...  653694093481
# ...                                                   ...           ...
# 704185  ZENNERS REFRIGERATED PORK WITH BACON SAUSAGE 1...  649522141281
# 704186  ZUMMOS REFRIGERATED PORK AND BEEF SAUSAGE 16 O...   81498331001
# 704187  ZUMMOS REFRIGERATED PORK SAUSAGE 12 OZ - 00814...   81498331082
# 704188  ZUMMOS REFRIGERATED PORK SAUSAGE 12 OZ - 00814...   81498880401
# 704189  ZUMMOS REFRIGERATED PORK SAUSAGE 36 OZ - 00814...   81498880431
#
#         Unit Sales  Volume Sales  Dollar Sales  Price per Unit  \
# 0        18.699034     18.699034    130.706246        6.990000
# 1        18.699034     18.699034    130.706246        6.990000
# 2       125.579780    125.579780    806.597630        6.422990
# 3        18.546104     13.909578    175.654875        9.471255
# 4        13.203283      9.902462    130.772051        9.904510
# ...            ...           ...           ...             ...
# 704185  172.690974    172.690974   1090.227419        6.313170
# 704186   12.715068     12.715068     56.560862        4.448333
# 704187  385.690406    289.267805   1537.209379        3.985604
# 704188  814.176710    610.632533   2681.771239        3.293844
# 704189   79.000000    177.750000    679.400000        8.600000
#
#         Price per Volume  Base Unit Sales  Base Volume Sales  \
# 0               6.990000        18.699034          18.699034
# 1               6.990000        18.699034          18.699034
# 2               6.422990       123.207541         123.207541
# 3              12.628340        18.546104          13.909578
# 4              13.206014        13.203283           9.902462
# ...                  ...              ...                ...
# 704185          6.313170       167.724890         167.724890
# 704186          4.448333        12.715068          12.715068
# 704187          5.314139       385.690406         289.267805
# 704188          4.391792       814.176710         610.632533
# 704189          3.822222        79.000000         177.750000
#
#         Base Dollar Sales  Incremental Units  Incremental Volume  \
# 0              130.706246                NaN                 NaN
# 1              130.706246                NaN                 NaN
# 2              792.212340           2.372240            2.372240
# 3              175.654875                NaN                 NaN
# 4              130.772051                NaN                 NaN
# ...                   ...                ...                 ...
# 704185        1067.283129           4.966084            4.966084
# 704186          56.560862                NaN                 NaN
# 704187        1537.209379                NaN                 NaN
# 704188        2681.771239                NaN                 NaN
# 704189         679.400000                NaN                 NaN
#
#         Incremental Dollars  ACV Weighted Distribution
# 0                       NaN                   0.021306
# 1                       NaN                   0.021306
# 2                  14.38529                   0.173211
# 3                       NaN                   0.056914
# 4                       NaN                   0.052690
# ...                     ...                        ...
# 704185             22.94429                   0.934328
# 704186                  NaN                   0.188748
# 704187                  NaN                   0.637834
# 704188                  NaN                   4.448174
# 704189                  NaN                   0.643488
#
# [704190 rows x 16 columns]

# %%
# Imputation
def imputation_process(row):
    row['Incremental Units'] = row['Unit Sales'] - row['Base Unit Sales']
    row['Incremental Volume'] = row['Volume Sales'] - row['Base Volume Sales']
    row['Incremental Dollars'] = row['Dollar Sales'] - row['Base Dollar Sales']
    return row

# Split Geography column and only save its location
def extract_location(col):
    return col.split(' - ')[0]

# convert time into year month and day
def parse_time(col):
    # Year, month, day
    sep_data = col.split('-')
    year = int('20' + sep_data[2])
    month = int(sep_data[0][-2:])
    day = int(sep_data[1])
    # Quarter of given date
    quarter = (month - 1) // 3 + 1
    return pd.Series([year, quarter, month], index = ['Year', 'Quarter', 'Month'])

# Split product column and only save company name and product name
def parse_product(col):  
    return col.split(' - ')[0]


# Based on length of company name, select product name
def extract_product_name(full_string, brand_name):
    brand_name_length = len(brand_name)
    words = full_string[brand_name_length:].strip()
    return words

# # Arrange columns order
def change_column_order(df):
    final_order = [
        'Geography', 'Year', 'Quarter', 'Manufacturer Name',
        'Brand Name', 'Product Name', 'Flavor / Scent', 'Meat Source',
        'Unit Sales', 'Volume Sales', 'Dollar Sales', 'Price per Unit', 
        'Price per Volume', 'Base Unit Sales', 'Base Volume Sales', 'Base Dollar Sales',
        'Incremental Units', 'Incremental Volume', 'Incremental Dollars', 
        'ACV Weighted Distribution'
    ]
    return df[final_order]

def merge_content(df1, df2):
    combined = df1.merge(df2, how = 'left', on = 'Product')
    return combined

def map_season(month):
    # Northern Hemisphere standard mapping
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Fall'


# Full tranform process
def transform_data(df, df2):
    table1 = merge_content(df, df2)
    # Used customized function
    table1['Geography'] = table1['Geography'].map(extract_location)
    table1[['Year', 'Quarter', 'Month']] = table1['Time'].apply(parse_time)
    table1['Product'] = table1['Product'].map(parse_product)
    table1['Product Name'] = table1.apply(lambda row: extract_product_name(row['Product'], row['Brand Name']), axis=1)
    #df['Product Name'] = df.apply(extract_product_name(df['Product'], df['Brand']), axis = 1)
    
    # Mapping quarter to seasonality
    table1['Season'] = table1['Month'].apply(map_season)
    # Change column order
    transformed = change_column_order(table1).apply(imputation_process, axis = 1)
    return transformed

# %%
rfg_dinner_ssg_2020 = transform_data(rfg_dinner_ssg, product_attribute)
rfg_dinner_ssg_2021 = transform_data(rfg_dinner_ssg2, product_attribute)
rfg_dinner_ssg_2022 = transform_data(rfg_dinner_ssg3, product_attribute)
rfg_dinner_ssg_2023 = transform_data(rfg_dinner_ssg4, product_attribute)
rfg_dinner_ssg_2024 = transform_data(rfg_dinner_ssg5, product_attribute)

# %%
# Combined & export
full_rfg_dinner_ssg = pd.concat([rfg_dinner_ssg_2020, rfg_dinner_ssg_2021, rfg_dinner_ssg_2022, rfg_dinner_ssg_2023, rfg_dinner_ssg_2024])
output_file = '/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/full_rfg_dinner_ssg.csv'
full_rfg_dinner_ssg.to_csv(output_file, index=False)
