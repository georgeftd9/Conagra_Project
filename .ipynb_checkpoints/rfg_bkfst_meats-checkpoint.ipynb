# %%
import pandas as pd

# %%
rfg_bkfst_meat = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Bkfst Meats_POS_2020.xlsx')
rfg_bkfst_meat2 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Bkfst Meats_POS_2021.xlsx')
rfg_bkfst_meat3 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Bkfst Meats_POS_2022.xlsx')
rfg_bkfst_meat4 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Bkfst Meats_POS_2023.xlsx')
rfg_bkfst_meat5 = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Data/Data/Rfg Bkfst Meats_POS_2024.xlsx')
product_attribute = pd.read_excel('/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/Conagra Cleaned Data/Product Attributes.xlsx')

# %%
rfg_bkfst_meat.head()
# Out:
#                         Geography                  Time  \
# 0  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 1  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 2  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 3  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 4  Total US - Multi Outlet + Conv  Week Ending 01-12-20
#
#                                              Product  UPC 13 digit  \
# 0  AL SAFA HALAL HICKORY SMOKED BEEF BACON SLICED...  624967012191
# 1  ALEXANDER & HORNUNG REGULAR PORK CANADIAN BACO...  717265101331
# 2  NOBRAND NATURAL HICKORY SMOKED PORK BACON ROUN...   40001311751
# 3  ARNOLDS REGULAR PORK BACON SLICED SLAB REFRIGE...   25325201281
# 4  ARNOLDS SMOKED BEEF BACON SLICED REFRIGERATED ...   25325120621
#
#     Unit Sales  Volume Sales  Dollar Sales  Price per Unit  Price per Volume  \
# 0    21.054711     15.791033    189.281850        8.990000         11.986667
# 1   153.454177     76.727089    592.433922        3.860657          7.721314
# 2  2737.757635    376.441675   3011.533399        1.100000          8.000000
# 3    89.436000    111.795000    808.034511        9.034779          7.227823
# 4  1121.928041    841.446031   8690.298488        7.745861         10.327814
#
#    Base Unit Sales  Base Volume Sales  Base Dollar Sales  Incremental Units  \
# 0        21.054711          15.791033         189.281850                NaN
# 1       153.454177          76.727089         592.433922                NaN
# 2      2737.757635         376.441675        3011.533399                NaN
# 3        89.436000         111.795000         808.034511                NaN
# 4      1121.928041         841.446031        8690.298488                0.0
#
#    Incremental Volume  Incremental Dollars  ACV Weighted Distribution
# 0                 NaN                  NaN                   0.003187
# 1                 NaN                  NaN                   0.041366
# 2                 NaN                  NaN                   0.024114
# 3                 NaN                  NaN                   0.048901
# 4                 0.0                  0.0                   0.752483

# %%
def imputation_process(row):
    row['Incremental Units'] = row['Unit Sales'] - row['Base Unit Sales']
    row['Incremental Volume'] = row['Volume Sales'] - row['Base Volume Sales']
    row['Incremental Dollars'] = row['Dollar Sales'] - row['Base Dollar Sales']
    return row

# Split Geography column and only save its location
def extract_location(col):
    return col.split(' - ')[0]

# convert time into year month and day
def parse_time(col):
    # Year, month, day
    sep_data = col.split('-')
    year = int('20' + sep_data[2])
    month = int(sep_data[0][-2:])
    day = int(sep_data[1])
    # Quarter of given date
    quarter = (month - 1) // 3 + 1
    return pd.Series([year, quarter, month], index = ['Year', 'Quarter', 'Month'])

# Split product column and only save company name and product name
def parse_product(col):  
    return col.split(' - ')[0]


# Based on length of company name, select product name
def extract_product_name(full_string, brand_name):
    brand_name_length = len(brand_name)
    words = full_string[brand_name_length:].strip()
    return words

# # Arrange columns order
def change_column_order(df):
    final_order = [
        'Geography', 'Year', 'Quarter', 'Manufacturer Name',
        'Brand Name', 'Product Name', 'Flavor / Scent', 'Meat Source',
        'Unit Sales', 'Volume Sales', 'Dollar Sales', 'Price per Unit', 
        'Price per Volume', 'Base Unit Sales', 'Base Volume Sales', 'Base Dollar Sales',
        'Incremental Units', 'Incremental Volume', 'Incremental Dollars', 
        'ACV Weighted Distribution'
    ]
    return df[final_order]

def merge_content(df1, df2):
    combined = df1.merge(df2, how = 'left', on = 'Product')
    return combined

def map_season(month):
    # Northern Hemisphere standard mapping
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Fall'


# Full tranform process
def transform_data(df, df2):
    table1 = merge_content(df, df2)
    # Used customized function
    table1['Geography'] = table1['Geography'].map(extract_location)
    table1[['Year', 'Quarter', 'Month']] = table1['Time'].apply(parse_time)
    table1['Product'] = table1['Product'].map(parse_product)
    table1['Product Name'] = table1.apply(lambda row: extract_product_name(row['Product'], row['Brand Name']), axis=1)
    #df['Product Name'] = df.apply(extract_product_name(df['Product'], df['Brand']), axis = 1)
    
    # Mapping quarter to seasonality
    table1['Season'] = table1['Month'].apply(map_season)
    # Change column order
    transformed = change_column_order(table1).apply(imputation_process, axis = 1)
    return transformed

# %%
rfg_bkfst_meat_2020 = transform_data(rfg_bkfst_meat, product_attribute)
rfg_bkfst_meat_2021 = transform_data(rfg_bkfst_meat2, product_attribute)
rfg_bkfst_meat_2022 = transform_data(rfg_bkfst_meat3, product_attribute)
rfg_bkfst_meat_2023 = transform_data(rfg_bkfst_meat4, product_attribute)
rfg_bkfst_meat_2024 = transform_data(rfg_bkfst_meat5, product_attribute)

# %%
# Combined & export
full_rfg_bkfst_meats = pd.concat([rfg_bkfst_meat_2020, rfg_bkfst_meat_2021, rfg_bkfst_meat_2022, rfg_bkfst_meat_2023, rfg_bkfst_meat_2024])
output_file = '/Users/fuqiaozhi/Desktop/UTD Semesters/Spring 2024/BUAN 6337/full_rfg_bkfst_meats.csv'
full_rfg_bkfst_meats.to_csv(output_file, index=False)
